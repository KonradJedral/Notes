# %% [markdown]
# # Łączenie danych z wielu obiektów

# %%
import pandas as pd
import numpy as np

# %%
products = pd.read_csv('./data/northwind-mongo-master/products.csv')

# %%
products.loc[products['ProductName'] == 'Ravioli Angelo']
# Out:
#     ProductID     ProductName  SupplierID  CategoryID   QuantityPerUnit  \
# 56         57  Ravioli Angelo          26           5  24 - 250 g pkgs.
#
#     UnitPrice  UnitsInStock  UnitsOnOrder  ReorderLevel  Discontinued
# 56       19.5            36             0            20             0

# %%
categories = pd.read_csv('./data/northwind-mongo-master/categories1.csv')

# %%
categories.loc[categories['CategoryID'] == 5]
# Out:
#    CategoryID    CategoryName Description
# 4           5  Grains/Cereals      Breads

# %%
suppliers = pd.read_csv('./data/northwind-mongo-master/suppliers.csv')

# %%
suppliers.loc[suppliers['SupplierID'] == 26]
# Out:
#     SupplierID           CompanyName       ContactName         ContactTitle  \
# 25          26  Pasta Buttini s.r.l.  Giovanni Giudici  Order Administrator
#
#                   Address     City Region PostalCode Country          Phone  \
# 25  Via dei Gelsomini 153  Salerno    NaN      84100   Italy  (089) 6547665
#
#               Fax HomePage
# 25  (089) 6547667      NaN

# %% [markdown]
# ## .append()
# doklejamy jeden DF od drugiego. Wspólne kolumny zostaną połączone, a występujące tylko w jednym DF później są dodawane

# %%
import pandas as pd
import numpy as np

# %%
suppliers = pd.read_csv('./data/northwind-mongo-master/suppliers.csv', usecols=['SupplierID', 'CompanyName', 'Country'])

# %%
customers = pd.read_csv('./data/northwind-mongo-master/customers.csv', usecols=['CustomerID', 'CompanyName', 'Country'])

# %%
suppliers.head()
# Out:
#    SupplierID                         CompanyName Country
# 0           1                      Exotic Liquids      UK
# 1           2          New Orleans Cajun Delights     USA
# 2           3           Grandma Kelly's Homestead     USA
# 3           4                       Tokyo Traders   Japan
# 4           5  Cooperativa de Quesos 'Las Cabras'   Spain

# %%
customers.head()
# Out:
#   CustomerID                         CompanyName  Country
# 0      ALFKI                 Alfreds Futterkiste  Germany
# 1      ANATR  Ana Trujillo Emparedados y helados   Mexico
# 2      ANTON            Antonio Moreno Taquer?­a   Mexico
# 3      AROUT                     Around the Horn       UK
# 4      BERGS                 Berglunds snabbk?¶p   Sweden

# %%
len(suppliers)
# Out:
# 29

# %%
len(customers)
# Out:
# 91

# %%
df_appended = suppliers.append(customers)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_5960\4044219764.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_appended = suppliers.append(customers)

# %%
df_appended.head(40)        # widzimy, że domyślnie indexy są przepisywane z DF takie jakie są
                            # przez co index przestaje być unikatowy

# %%
df_appended = suppliers.append(customers, ignore_index=True)

# %%
df_appended.head(40)         # dzięki ignore_index index został stworzony na nowo dla połączonej tabeli i jest unikalny

# %% [markdown]
# #### Łączenie dwóch kolumn w jedną
# <br>Musimy zmienić nazwy kolumn, tak żeby miały taką samą nazwę

# %%
supplier2 = suppliers.copy()
customer2 = customers.copy()

# %%
supplier2.rename({'SupplierID' : 'CustomerID'}, axis = 'columns', inplace = True)

# %%
supplier2.head()
# Out:
#    CustomerID                         CompanyName Country
# 0           1                      Exotic Liquids      UK
# 1           2          New Orleans Cajun Delights     USA
# 2           3           Grandma Kelly's Homestead     USA
# 3           4                       Tokyo Traders   Japan
# 4           5  Cooperativa de Quesos 'Las Cabras'   Spain

# %%
supplier2.append(customer2, ignore_index=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_5960\3999593382.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   supplier2.append(customer2, ignore_index=True)
#     CustomerID                         CompanyName  Country
# 0            1                      Exotic Liquids       UK
# 1            2          New Orleans Cajun Delights      USA
# 2            3           Grandma Kelly's Homestead      USA
# 3            4                       Tokyo Traders    Japan
# 4            5  Cooperativa de Quesos 'Las Cabras'    Spain
# ..         ...                                 ...      ...
# 115      WARTH                      Wartian Herkku  Finland
# 116      WELLI              Wellington Importadora   Brazil
# 117      WHITC                White Clover Markets      USA
# 118      WILMK                         Wilman Kala  Finland
# 119      WOLZA                      Wolski  Zajazd   Poland
#
# [120 rows x 3 columns]

# %% [markdown]
# ## pd.concat()
# możemy do jednego DF dołączać kilka DF

# %%
df_concatenated = pd.concat([suppliers, customers])

# %%
len(df_concatenated)
# Out:
# 120

# %%
df_concatenated.head(40)
# Out:
#     SupplierID                             CompanyName      Country CustomerID
# 0          1.0                          Exotic Liquids           UK        NaN
# 1          2.0              New Orleans Cajun Delights          USA        NaN
# 2          3.0               Grandma Kelly's Homestead          USA        NaN
# 3          4.0                           Tokyo Traders        Japan        NaN
# 4          5.0      Cooperativa de Quesos 'Las Cabras'        Spain        NaN
# 5          6.0                                Mayumi's        Japan        NaN
# 6          7.0                            Pavlova Ltd.    Australia        NaN
# 7          8.0                 Specialty Biscuits Ltd.           UK        NaN
# 8          9.0                        PB Knäckebröd AB       Sweden        NaN
# 9         10.0               Refrescos Americanas LTDA       Brazil        NaN
# 10        11.0             Heli Süßwaren GmbH & Co. KG      Germany        NaN
# 11        12.0       Plutzer Lebensmittelgroßmärkte AG      Germany        NaN
# 12        13.0  Nord-Ost-Fisch Handelsgesellschaft mbH      Germany        NaN
# 13        14.0                 Formaggi Fortini s.r.l.        Italy        NaN
# 14        15.0                         Norske Meierier       Norway        NaN
# 15        16.0                       Bigfoot Breweries          USA        NaN
# 16        17.0                       Svensk Sjöföda AB       Sweden        NaN
# 17        18.0              Aux joyeux ecclésiastiques       France        NaN
# 18        19.0             New England Seafood Cannery          USA        NaN
# 19        20.0                            Leka Trading    Singapore        NaN
# 20        21.0                              Lyngbysild      Denmark        NaN
# 21        22.0                     Zaanse Snoepfabriek  Netherlands        NaN
# 22        23.0                               Karkki Oy      Finland        NaN
# 23        24.0                              G'day Mate    Australia        NaN
# 24        25.0                               Ma Maison       Canada        NaN
# 25        26.0                    Pasta Buttini s.r.l.        Italy        NaN
# 26        27.0                      Escargots Nouveaux       France        NaN
# 27        28.0                            Gai pâturage       France        NaN
# 28        29.0                        Forêts d'érables       Canada        NaN
# 0          NaN                     Alfreds Futterkiste      Germany      ALFKI
# 1          NaN      Ana Trujillo Emparedados y helados       Mexico      ANATR
# 2          NaN                Antonio Moreno Taquer?­a       Mexico      ANTON
# 3          NaN                         Around the Horn           UK      AROUT
# 4          NaN                     Berglunds snabbk?¶p       Sweden      BERGS
# 5          NaN                 Blauer See Delikatessen      Germany      BLAUS
# 6          NaN               Blondesddsl p?¨re et fils       France      BLONP
# 7          NaN              B??lido Comidas preparadas        Spain      BOLID
# 8          NaN                                Bon app'       France      BONAP
# 9          NaN                   Bottom-Dollar Markets       Canada      BOTTM
# 10         NaN                           B's Beverages           UK      BSBEV

# %% [markdown]
# Żeby zrobić unikalny index dopisujemy ignore_index=True

# %%
df_concatenated = pd.concat([suppliers, customers], ignore_index=True)

# %% [markdown]
# Żeby połączyć dwie kolumny w jedną - tak jak przy append najpierw przygotowujemy jedną z DF tak, żeby miała nazwy kolumn takie same jak w drugim DF

# %%
supplier2 = suppliers.copy()

# %%
supplier2.rename({'SupplierID' : 'CustomerID'}, axis = 'columns', inplace = True)

# %%
df_concatenated = pd.concat([supplier2, customers], ignore_index=True)

# %% [markdown]
# ## Ćwiczenie
# .append() i .concat()

# %%
import pandas as pd
import numpy as np

# %%
mrbean = pd.read_csv('./data/mrbean_facebook_statuses_join.csv', usecols=['status_message_mrbean','status_type','num_likes'])

# %%
nasa = pd.read_csv('./data/nasa_facebook_statuses_join.csv', usecols=['status_message_nasa','status_type','num_likes']

# %%
mrbean.head()

# %%
nasa.head()

# %%
fb = mrbean.append(nasa, sort=True)

# %%
fb.head()

# %%
fb.tail()

# %%
fb.loc[0]

# %%
fb = mrbean.append(nasa, sort=True, ignore_index=True)

# %%
fb.loc[0]

# %%
mrbean.rename({'status_message_mrbean' : 'status_message'}, axis=1, inplace=True)

# %%
nasa.rename({'status_message_nasa' : 'status_message'}, axis=1, inplace=True)

# %%
fb = mrbean.append(nasa, sort=True, ignore_index=True)

# %%
fb.head()

# %%
fb = pd.concat([mrbean, nasa], ignore_index=True)

# %% [markdown]
# ## .join()
# Łączenie dwóch DF w taki sposób, że do jednego DF dodajemy kolumny z drugiego DF. Łącząc dane opierając się na indexach

# %%
prod_1 = pd.read_csv('./data/northwind-mongo-master/products.csv', usecols=['ProductID', 'ProductName'], index_col=['ProductID'])

# %%
prod_2 = pd.read_csv('./data/northwind-mongo-master/products.csv', usecols=['ProductID', 'UnitPrice', 'UnitsInStock'], index_col=['ProductID'])

# %%
prod_1.head()
# Out:
#                             ProductName
# ProductID
# 1                                  Chai
# 2                                 Chang
# 3                         Aniseed Syrup
# 4          Chef Anton's Cajun Seasoning
# 5                Chef Anton's Gumbo Mix

# %%
prod_2.head()
# Out:
#            UnitPrice  UnitsInStock
# ProductID
# 1              18.00            39
# 2              19.00            17
# 3              10.00            13
# 4              22.00            53
# 5              21.35             0

# %% [markdown]
# Łączymy za pomocą .join()

# %%
prod_1.join(prod_2).head()
# Out:
#                             ProductName  UnitPrice  UnitsInStock
# ProductID
# 1                                  Chai      18.00            39
# 2                                 Chang      19.00            17
# 3                         Aniseed Syrup      10.00            13
# 4          Chef Anton's Cajun Seasoning      22.00            53
# 5                Chef Anton's Gumbo Mix      21.35             0

# %% [markdown]
# ### .join()
# (how='left' lub 'right', domyślnie left - czyli do DF podanego jako pierwszy (prod_1) dodajemy te wartości z drugiego DF (right), które pokrywaja się z pierwszym DF (left). Te, które są w (right), ale nie ma ich w (left) nie są dodawane.<br> Jeśli how='right' to działa w drugą stronę.
# <br> on=' ' - podajemy nazwę kolumny z pierwszego DF, z którą chcemy połączyć index drugiego DF

# %%
categories = pd.read_csv('./data/northwind-mongo-master/categories1.csv', usecols=['CategoryID', 'CategoryName', 'Description'])

# %%
products = pd.read_csv('./data/northwind-mongo-master/products.csv', usecols=['ProductID', 'ProductName', 'UnitPrice', 'CategoryID'])

# %%
categories.head()
# Out:
#    CategoryID    CategoryName              Description
# 0           1       Beverages              Soft drinks
# 1           2      Condiments  Sweet and savory sauces
# 2           3     Confections                 Desserts
# 3           4  Dairy Products                  Cheeses
# 4           5  Grains/Cereals                   Breads

# %%
products.head()
# Out:
#    ProductID                   ProductName  CategoryID  UnitPrice
# 0          1                          Chai           1      18.00
# 1          2                         Chang           1      19.00
# 2          3                 Aniseed Syrup           2      10.00
# 3          4  Chef Anton's Cajun Seasoning           2      22.00
# 4          5        Chef Anton's Gumbo Mix           2      21.35

# %% [markdown]
# Najpierw musimy ustalić wspólny index, po którym będziemy łączyć dwa DF

# %%
categories.set_index('CategoryID', inplace=True)

# %%
categories.head()
# Out:
#               CategoryName              Description
# CategoryID
# 1                Beverages              Soft drinks
# 2               Condiments  Sweet and savory sauces
# 3              Confections                 Desserts
# 4           Dairy Products                  Cheeses
# 5           Grains/Cereals                   Breads

# %%
products.join(other=categories, on ='CategoryID')              # bez other a categories w ' '
# Out:
#     ProductID                      ProductName  CategoryID  UnitPrice  \
# 0           1                             Chai           1      18.00
# 1           2                            Chang           1      19.00
# 2           3                    Aniseed Syrup           2      10.00
# 3           4     Chef Anton's Cajun Seasoning           2      22.00
# 4           5           Chef Anton's Gumbo Mix           2      21.35
# ..        ...                              ...         ...        ...
# 72         73                       Röd Kaviar           8      15.00
# 73         74                    Longlife Tofu           7      10.00
# 74         75             Rhönbräu Klosterbier           1       7.75
# 75         76                     Lakkalikööri           1      18.00
# 76         77  Original Frankfurter grüne Soße           2      13.00
#
#    CategoryName                Description
# 0     Beverages                Soft drinks
# 1     Beverages                Soft drinks
# 2    Condiments    Sweet and savory sauces
# 3    Condiments    Sweet and savory sauces
# 4    Condiments    Sweet and savory sauces
# ..          ...                        ...
# 72      Seafood           Seaweed and fish
# 73      Produce  Dried fruit and bean curd
# 74    Beverages                Soft drinks
# 75    Beverages                Soft drinks
# 76   Condiments    Sweet and savory sauces
#
# [77 rows x 6 columns]

# %% [markdown]
# ## Ćwiczenie
# .join()

# %%
import pandas as pd
import numpy as np

# %%
customer_names = pd.read_csv('./data/northwind-mongo-master/customers.csv', usecols=['CustomerID','CompanyName'])

# %%
customer_cities = pd.read_csv('./data/northwind-mongo-master/customers.csv', usecols=['CustomerID','City','Country'])

# %%
len(customer_names)
# Out:
# 91

# %%
len(customer_cities)
# Out:
# 91

# %%
customer_names.set_index('CustomerID', inplace=True)

# %%
customer_cities.set_index('CustomerID', inplace=True)

# %%
customer_names.join(customer_cities).head()
# Out:
#                                    CompanyName          City  Country
# CustomerID
# ALFKI                      Alfreds Futterkiste        Berlin  Germany
# ANATR       Ana Trujillo Emparedados y helados  M?©xico D.F.   Mexico
# ANTON                 Antonio Moreno Taquer?­a  M?©xico D.F.   Mexico
# AROUT                          Around the Horn        London       UK
# BERGS                      Berglunds snabbk?¶p        Lule??   Sweden

# %%
len(customer_names.join(customer_cities))
# Out:
# 91

# %%
customer_names.reset_index(inplace=True)

# %%
customer_names.join(customer_cities, on='CustomerID').head()
# Out:
#   CustomerID                         CompanyName          City  Country
# 0      ALFKI                 Alfreds Futterkiste        Berlin  Germany
# 1      ANATR  Ana Trujillo Emparedados y helados  M?©xico D.F.   Mexico
# 2      ANTON            Antonio Moreno Taquer?­a  M?©xico D.F.   Mexico
# 3      AROUT                     Around the Horn        London       UK
# 4      BERGS                 Berglunds snabbk?¶p        Lule??   Sweden

# %%
len(customer_names.join(customer_cities, on='CustomerID'))
# Out:
# 91

# %% [markdown]
# ## .Merge()
# Domyślnie how='inner' - Część wspólna dwóch zbiorów
# <br> how='left' - Wszystkie wiersze z lewego DF, w tym część wspólna
# <br> how='right' - Wszsytkie wiersze z prawego DF, w tym część wspólna
# <br> how='outer' - Wszystkie wartości z obydwu DF
# <br> suffixes=[] - Sufix dodawany do nazw kolumn z danymi z łączonych DF
# <br> indicator=True - dodaje na końcu nową kolumnę z informacją, z którego DF jest pobrana wartość

# %%
cat1 = pd.read_csv('./data/northwind-mongo-master/categories_del_1.csv', usecols=['CategoryID', 'CategoryName'])

# %%
cat2 = pd.read_csv('./data/northwind-mongo-master/categories_del_2.csv', usecols=['CategoryID', 'CategoryName'])

# %%
cat1
# Out:
#    CategoryID    CategoryName
# 0           2      Condiments
# 1           3     Confections
# 2           4  Dairy Products
# 3           5  Grains/Cereals
# 4           6    Meat/Poultry
# 5           7         Produce
# 6           8         Seafood

# %%
cat2
# Out:
#    CategoryID    CategoryName
# 0           1       Beverages
# 1           2      Condiments
# 2           3     Confections
# 3           4  Dairy Products
# 4           7         Produce
# 5           8         Seafood

# %%
cat1.merge(cat2)          # Wyświetli DF ze wspólnymi wartościami występującymi w obydwu DF
# Out:
#    CategoryID    CategoryName
# 0           2      Condiments
# 1           3     Confections
# 2           4  Dairy Products
# 3           7         Produce
# 4           8         Seafood

# %%
cat1.merge(cat2, on='CategoryID')          # Wyświetli DF z osobnymi kolumnami dla wartości z obydwu DF
# Out:
#    CategoryID  CategoryName_x  CategoryName_y
# 0           2      Condiments      Condiments
# 1           3     Confections     Confections
# 2           4  Dairy Products  Dairy Products
# 3           7         Produce         Produce
# 4           8         Seafood         Seafood

# %%
cat1.merge(cat2, on='CategoryID', suffixes=['_1', '_2'])     # Sufix dodawany do nazw kolumn z danymi z łączonych DF
# Out:
#    CategoryID  CategoryName_1  CategoryName_2
# 0           2      Condiments      Condiments
# 1           3     Confections     Confections
# 2           4  Dairy Products  Dairy Products
# 3           7         Produce         Produce
# 4           8         Seafood         Seafood

# %%
cat1.merge(cat2, on='CategoryID', suffixes=['_1', '_2'], how='outer')
# Out:
#    CategoryID  CategoryName_1  CategoryName_2
# 0           2      Condiments      Condiments
# 1           3     Confections     Confections
# 2           4  Dairy Products  Dairy Products
# 3           5  Grains/Cereals             NaN
# 4           6    Meat/Poultry             NaN
# 5           7         Produce         Produce
# 6           8         Seafood         Seafood
# 7           1             NaN       Beverages

# %%
cat1.merge(cat2, on='CategoryID', suffixes=['_1', '_2'], how='outer', indicator=True)
# Out:
#    CategoryID  CategoryName_1  CategoryName_2      _merge
# 0           2      Condiments      Condiments        both
# 1           3     Confections     Confections        both
# 2           4  Dairy Products  Dairy Products        both
# 3           5  Grains/Cereals             NaN   left_only
# 4           6    Meat/Poultry             NaN   left_only
# 5           7         Produce         Produce        both
# 6           8         Seafood         Seafood        both
# 7           1             NaN       Beverages  right_only

# %%
catMerged = cat1.merge(cat2, on='CategoryID', suffixes=['_1', '_2'], how='outer', indicator=True)

# %% [markdown]
# Sprawdzamy, czy w catMerged są wartości, które znajdowały się tylko po lewej stronie \

# %%
catMerged['_merge'] == "left_only"
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# 5    False
# 6    False
# 7    False
# Name: _merge, dtype: bool

# %%
catMerged[catMerged['_merge'] == "left_only"]
# Out:
#    CategoryID  CategoryName_1 CategoryName_2     _merge
# 3           5  Grains/Cereals            NaN  left_only
# 4           6    Meat/Poultry            NaN  left_only

# %% [markdown]
# ## Ćwiczenie
# Merge()

# %%
f_2015 = cat1 = pd.read_csv('./data/Fortune_500_2015.csv', usecols=['rank', 'company'])

# %%
f_2016 = cat1 = pd.read_csv('./data/Fortune_500_2016.csv', usecols=['rank', 'company'])

# %%
f_2015
# Out:
#      rank                    company
# 0       1                    Walmart
# 1       2                Exxon Mobil
# 2       3                    Chevron
# 3       4         Berkshire Hathaway
# 4       5                      Apple
# ..    ...                        ...
# 495   496  Pioneer Natural Resources
# 496   497          Wyndham Worldwide
# 497   498              Owens Corning
# 498   499                  Alleghany
# 499   500      McGraw Hill Financial
#
# [500 rows x 2 columns]

# %%
f_2016
# Out:
#      rank                   company
# 0       1                   Walmart
# 1       2               Exxon Mobil
# 2       3                     Apple
# 3       4        Berkshire Hathaway
# 4       5                  McKesson
# ..    ...                       ...
# 495   496  Telephone & Data Systems
# 496   497  First American Financial
# 497   498                       NVR
# 498   499      Cincinnati Financial
# 499   500         Burlington Stores
#
# [500 rows x 2 columns]

# %%
f_2015.merge(f_2016, on='company', suffixes=['_2015', '_2016'])

# %%
companies_2015_2016 = f_2015.merge(f_2016, on='company', suffixes=['_2015', '_2016'])

# %%
companies_2015_2016 = companies_2015_2016[['company', 'rank_2015', 'rank_2016']]

# %%
companies_2015_2016.head()
# Out:
#               company  rank_2015  rank_2016
# 0             Walmart          1          1
# 1         Exxon Mobil          2          2
# 2             Chevron          3         14
# 3  Berkshire Hathaway          4          4
# 4               Apple          5          3

# %%
companies_2015_2016[companies_2015_2016["company"] == "Microsoft"]
# Out:
#       company  rank_2015  rank_2016
# 30  Microsoft         31         25

# %%
companies_2015_2016 = f_2015.merge(f_2016, on='company', suffixes=['_2015', '_2016'], indicator=True)

# %%
only_2015 = companies_2015_2016[companies_2015_2016["_merge"] == "left_only"]

# %%
only_2016 = companies_2015_2016[companies_2015_2016["_merge"] == "right_only"]

# %% [markdown]
# ## .merge(how='outer')

# %%
product = pd.read_csv('./data/northwind-mongo-master/products.csv', usecols=['ProductID', 'ProductName'])

# %%
orderedProducts = pd.read_csv('./data/northwind-mongo-master/order-details_del.csv', usecols=['OrderID', 'ProductID', 'UnitPrice', 'Quantity'])

# %%
product.head()
# Out:
#    ProductID                   ProductName
# 0          1                          Chai
# 1          2                         Chang
# 2          3                 Aniseed Syrup
# 3          4  Chef Anton's Cajun Seasoning
# 4          5        Chef Anton's Gumbo Mix

# %%
orderedProducts
# Out:
#      OrderID  ProductID  UnitPrice  Quantity
# 0      10331         54        5.9        15
# 1      10332         18       50.0        40
# 2      10332         42       11.2        10
# 3      10332         47        7.6        16
# 4      10333         14       18.6        10
# ..       ...        ...        ...       ...
# 284    10439         64       26.6         6
# 285    10439         74        8.0        30
# 286    10440          2       15.2        45
# 287    10440         16       13.9        49
# 288    10440         29       99.0        24
#
# [289 rows x 4 columns]

# %% [markdown]
# Chcemy znaleźć wszystkie produkty, które się nie sprzedały

# %%
merged = product.merge(right=orderedProducts, on='ProductID', how='outer', indicator=True)

# %%
merged
# Out:
#      ProductID                      ProductName  OrderID  UnitPrice  Quantity  \
# 0            1                             Chai  10348.0       14.4      15.0
# 1            1                             Chai  10354.0       14.4      12.0
# 2            1                             Chai  10370.0       14.4      15.0
# 3            1                             Chai  10406.0       14.4      10.0
# 4            1                             Chai  10413.0       14.4      24.0
# ..         ...                              ...      ...        ...       ...
# 289         77  Original Frankfurter grüne Soße  10366.0       10.4       5.0
# 290         77  Original Frankfurter grüne Soße  10367.0       10.4       7.0
# 291         77  Original Frankfurter grüne Soße  10399.0       10.4      14.0
# 292         77  Original Frankfurter grüne Soße  10417.0       10.4      35.0
# 293         77  Original Frankfurter grüne Soße  10421.0       10.4      10.0
#
#     _merge
# 0     both
# 1     both
# 2     both
# 3     both
# 4     both
# ..     ...
# 289   both
# 290   both
# 291   both
# 292   both
# 293   both
#
# [294 rows x 6 columns]

# %%
merged['_merge'].value_counts()               # wynik left_only jest 5, czyli 5 różnych produktów nie udało się sprzedać
# Out:
# both          289
# left_only       5
# right_only      0
# Name: _merge, dtype: int64

# %%
filter = merged['_merge'] == 'left_only'

# %%
merged[filter]
# Out:
#      ProductID                   ProductName  OrderID  UnitPrice  Quantity  \
# 16           6  Grandma's Boysenberry Spread      NaN        NaN       NaN
# 38          15                  Genen Shouyu      NaN        NaN       NaN
# 85          27            Schoggi Schokolade      NaN        NaN       NaN
# 242         66     Louisiana Hot Spiced Okra      NaN        NaN       NaN
# 243         67     Laughing Lumberjack Lager      NaN        NaN       NaN
#
#         _merge
# 16   left_only
# 38   left_only
# 85   left_only
# 242  left_only
# 243  left_only

# %% [markdown]
# Ani razu nie sprzedały się powyższe produkty
# <br> W tym przypadku można to też zrobić tak:

# %%
mergedLeft = product.merge(right=orderedProducts, on='ProductID', how='left', indicator=True)

# %%
mergedLeft.head(10)
# Out:
#    ProductID ProductName  OrderID  UnitPrice  Quantity _merge
# 0          1        Chai  10348.0       14.4      15.0   both
# 1          1        Chai  10354.0       14.4      12.0   both
# 2          1        Chai  10370.0       14.4      15.0   both
# 3          1        Chai  10406.0       14.4      10.0   both
# 4          1        Chai  10413.0       14.4      24.0   both
# 5          2       Chang  10335.0       15.2       7.0   both
# 6          2       Chang  10342.0       15.2      24.0   both
# 7          2       Chang  10393.0       15.2      25.0   both
# 8          2       Chang  10418.0       15.2      60.0   both
# 9          2       Chang  10435.0       15.2      10.0   both

# %%
mergedLeft[mergedLeft['_merge'] == 'left_only']
# Out:
#      ProductID                   ProductName  OrderID  UnitPrice  Quantity  \
# 16           6  Grandma's Boysenberry Spread      NaN        NaN       NaN
# 38          15                  Genen Shouyu      NaN        NaN       NaN
# 85          27            Schoggi Schokolade      NaN        NaN       NaN
# 242         66     Louisiana Hot Spiced Okra      NaN        NaN       NaN
# 243         67     Laughing Lumberjack Lager      NaN        NaN       NaN
#
#         _merge
# 16   left_only
# 38   left_only
# 85   left_only
# 242  left_only
# 243  left_only

# %% [markdown]
# ## Ćwiczenie
# merge outer

# %%
import pandas as pd
import numpy as np

# %%
suppliers = pd.read_csv('./data/northwind-mongo-master/suppliers _del_1.csv', usecols=['SupplierID', 'CompanyName', 'City'])

# %%
products = pd.read_csv('./data/northwind-mongo-master/products_del_1.csv', usecols=['ProductID', 'ProductName', 'SupplierID'])

# %%
suppliers.head(10)
# Out:
#    SupplierID                         CompanyName         City
# 0           1                      Exotic Liquids       London
# 1           2          New Orleans Cajun Delights  New Orleans
# 2           3           Grandma Kelly's Homestead    Ann Arbor
# 3           4                       Tokyo Traders        Tokyo
# 4           5  Cooperativa de Quesos 'Las Cabras'       Oviedo
# 5           6                            Mayumi's        Osaka
# 6           7                        Pavlova Ltd.    Melbourne
# 7           8             Specialty Biscuits Ltd.   Manchester
# 8          10           Refrescos Americanas LTDA    Sao Paulo
# 9          11         Heli Süßwaren GmbH & Co. KG       Berlin

# %%
len(suppliers)
# Out:
# 27

# %%
products.head()
# Out:
#    ProductID                   ProductName  SupplierID
# 0          1                          Chai           1
# 1          2                         Chang           1
# 2          3                 Aniseed Syrup           1
# 3          4  Chef Anton's Cajun Seasoning           2
# 4          5        Chef Anton's Gumbo Mix           2

# %%
len(products)
# Out:
# 75

# %%
prodAndSupInner = products.merge(right=suppliers, how='inner', on='SupplierID', indicator=True)

# %%
prodAndSupInner
# Out:
#     ProductID                   ProductName  SupplierID  \
# 0           1                          Chai           1
# 1           2                         Chang           1
# 2           3                 Aniseed Syrup           1
# 3           4  Chef Anton's Cajun Seasoning           2
# 4           5        Chef Anton's Gumbo Mix           2
# ..        ...                           ...         ...
# 65         56        Gnocchi di nonna Alice          26
# 66         57                Ravioli Angelo          26
# 67         60             Camembert Pierrot          28
# 68         61                Sirop d'érable          29
# 69         62                Tarte au sucre          29
#
#                    CompanyName           City _merge
# 0               Exotic Liquids         London   both
# 1               Exotic Liquids         London   both
# 2               Exotic Liquids         London   both
# 3   New Orleans Cajun Delights    New Orleans   both
# 4   New Orleans Cajun Delights    New Orleans   both
# ..                         ...            ...    ...
# 65        Pasta Buttini s.r.l.        Salerno   both
# 66        Pasta Buttini s.r.l.        Salerno   both
# 67                Gai pâturage         Annecy   both
# 68            Forêts d'érables  Ste-Hyacinthe   both
# 69            Forêts d'érables  Ste-Hyacinthe   both
#
# [70 rows x 6 columns]

# %%
prodAndSupInner['_merge'].value_counts()
# Out:
# both          70
# left_only      0
# right_only     0
# Name: _merge, dtype: int64

# %%
prodAndSupOuter = products.merge(right=suppliers, how='outer', on='SupplierID', indicator=True)

# %%
prodAndSupOuter
# Out:
#     ProductID                   ProductName  SupplierID  \
# 0         1.0                          Chai           1
# 1         2.0                         Chang           1
# 2         3.0                 Aniseed Syrup           1
# 3         4.0  Chef Anton's Cajun Seasoning           2
# 4         5.0        Chef Anton's Gumbo Mix           2
# ..        ...                           ...         ...
# 71       57.0                Ravioli Angelo          26
# 72       60.0             Camembert Pierrot          28
# 73       61.0                Sirop d'érable          29
# 74       62.0                Tarte au sucre          29
# 75        NaN                           NaN          27
#
#                    CompanyName           City      _merge
# 0               Exotic Liquids         London        both
# 1               Exotic Liquids         London        both
# 2               Exotic Liquids         London        both
# 3   New Orleans Cajun Delights    New Orleans        both
# 4   New Orleans Cajun Delights    New Orleans        both
# ..                         ...            ...         ...
# 71        Pasta Buttini s.r.l.        Salerno        both
# 72                Gai pâturage         Annecy        both
# 73            Forêts d'érables  Ste-Hyacinthe        both
# 74            Forêts d'érables  Ste-Hyacinthe        both
# 75          Escargots Nouveaux       Montceau  right_only
#
# [76 rows x 6 columns]

# %%
prodAndSupOuter['_merge'].value_counts()
# Out:
# both          70
# left_only      5
# right_only     1
# Name: _merge, dtype: int64

# %%
prodAndSupOuter[prodAndSupOuter['_merge'] == 'right_only']                # Dostawcy, którzy nic nie dostarczają
# Out:
#     ProductID ProductName  SupplierID         CompanyName      City  \
# 75        NaN         NaN          27  Escargots Nouveaux  Montceau
#
#         _merge
# 75  right_only

# %%
prodAndSupOuter[prodAndSupOuter['_merge'] == 'left_only']                 # Produkty, które nie mają dostawców
# Out:
#     ProductID          ProductName  SupplierID CompanyName City     _merge
# 27       22.0  Gustaf's Knäckebröd           9         NaN  NaN  left_only
# 28       23.0             Tunnbröd           9         NaN  NaN  left_only
# 48       36.0          Inlagd Sill          17         NaN  NaN  left_only
# 49       37.0           Gravad lax          17         NaN  NaN  left_only
# 50       73.0           Röd Kaviar          17         NaN  NaN  left_only

# %% [markdown]
# ## .merge LEFT i RIGHT

# %%
product = pd.read_csv('./data/northwind-mongo-master/products.csv', usecols=['ProductID', 'ProductName'])

# %%
orderedProducts = pd.read_csv('./data/northwind-mongo-master/order-details_del.csv', usecols=['OrderID', 'ProductID', 'UnitPrice', 'Quantity'])

# %%
product
# Out:
#     ProductID                      ProductName
# 0           1                             Chai
# 1           2                            Chang
# 2           3                    Aniseed Syrup
# 3           4     Chef Anton's Cajun Seasoning
# 4           5           Chef Anton's Gumbo Mix
# ..        ...                              ...
# 72         73                       Röd Kaviar
# 73         74                    Longlife Tofu
# 74         75             Rhönbräu Klosterbier
# 75         76                     Lakkalikööri
# 76         77  Original Frankfurter grüne Soße
#
# [77 rows x 2 columns]

# %%
orderedProducts
# Out:
#      OrderID  ProductID  UnitPrice  Quantity
# 0      10331         54        5.9        15
# 1      10332         18       50.0        40
# 2      10332         42       11.2        10
# 3      10332         47        7.6        16
# 4      10333         14       18.6        10
# ..       ...        ...        ...       ...
# 284    10439         64       26.6         6
# 285    10439         74        8.0        30
# 286    10440          2       15.2        45
# 287    10440         16       13.9        49
# 288    10440         29       99.0        24
#
# [289 rows x 4 columns]

# %%
merged = product.merge(right=orderedProducts, on='ProductID', how='left', indicator=True)

# %%
merged
# Out:
#      ProductID                      ProductName  OrderID  UnitPrice  Quantity  \
# 0            1                             Chai  10348.0       14.4      15.0
# 1            1                             Chai  10354.0       14.4      12.0
# 2            1                             Chai  10370.0       14.4      15.0
# 3            1                             Chai  10406.0       14.4      10.0
# 4            1                             Chai  10413.0       14.4      24.0
# ..         ...                              ...      ...        ...       ...
# 289         77  Original Frankfurter grüne Soße  10366.0       10.4       5.0
# 290         77  Original Frankfurter grüne Soße  10367.0       10.4       7.0
# 291         77  Original Frankfurter grüne Soße  10399.0       10.4      14.0
# 292         77  Original Frankfurter grüne Soße  10417.0       10.4      35.0
# 293         77  Original Frankfurter grüne Soße  10421.0       10.4      10.0
#
#     _merge
# 0     both
# 1     both
# 2     both
# 3     both
# 4     both
# ..     ...
# 289   both
# 290   both
# 291   both
# 292   both
# 293   both
#
# [294 rows x 6 columns]

# %%
merged['_merge'].value_counts()
# Out:
# both          289
# left_only       5
# right_only      0
# Name: _merge, dtype: int64

# %%
merged = product.merge(right=orderedProducts, on='ProductID', how='right', indicator=True)

# %%
merged
# Out:
#      ProductID                    ProductName  OrderID  UnitPrice  Quantity  \
# 0           54                      Tourtière    10331        5.9        15
# 1           18               Carnarvon Tigers    10332       50.0        40
# 2           42  Singaporean Hokkien Fried Mee    10332       11.2        10
# 3           47                  Zaanse koeken    10332        7.6        16
# 4           14                           Tofu    10333       18.6        10
# ..         ...                            ...      ...        ...       ...
# 284         64      Wimmers gute Semmelknödel    10439       26.6         6
# 285         74                  Longlife Tofu    10439        8.0        30
# 286          2                          Chang    10440       15.2        45
# 287         16                        Pavlova    10440       13.9        49
# 288         29        Thüringer Rostbratwurst    10440       99.0        24
#
#     _merge
# 0     both
# 1     both
# 2     both
# 3     both
# 4     both
# ..     ...
# 284   both
# 285   both
# 286   both
# 287   both
# 288   both
#
# [289 rows x 6 columns]

# %%
merged['_merge'].value_counts()
# Out:
# both          289
# left_only       0
# right_only      0
# Name: _merge, dtype: int64

# %% [markdown]
# ## Ćwiczenie
# left&right merge

# %%
import pandas as pd
import numpy as np

# %%
suppliers = pd.read_csv('./data/northwind-mongo-master/suppliers.csv', usecols=['SupplierID', 'CompanyName', 'City'])

# %%
products = pd.read_csv('./data/northwind-mongo-master/products_del_2.csv', usecols=['ProductID', 'ProductName', 'SupplierID'])

# %%
SupProdLM = suppliers.merge(right=products, on='SupplierID', how='left', indicator=True)

# %%
len(suppliers)
# Out:
# 29

# %%
len(products)
# Out:
# 68

# %%
len(SupProdLM)
# Out:
# 70

# %%
SupProdLM['_merge'].value_counts()
# Out:
# both          68
# left_only      2
# right_only     0
# Name: _merge, dtype: int64

# %%
SupProdLM[SupProdLM['_merge'] == 'left_only']
# Out:
#     SupplierID                 CompanyName         City  ProductID  \
# 2            2  New Orleans Cajun Delights  New Orleans        NaN
# 67          27          Escargots Nouveaux     Montceau        NaN
#
#    ProductName     _merge
# 2          NaN  left_only
# 67         NaN  left_only

# %% [markdown]
# ## Merge cd

# %%
products = pd.read_csv('./data/northwind-mongo-master/products.csv', usecols=['ProductID', 'ProductName', 'CategoryID','UnitPrice'])

# %%
categories = pd.read_csv('./data/northwind-mongo-master/categories1.csv', usecols=['CategoryID','CategoryName', 'Description'])

# %%
products.head(10)
# Out:
#    ProductID                      ProductName  CategoryID  UnitPrice
# 0          1                             Chai           1      18.00
# 1          2                            Chang           1      19.00
# 2          3                    Aniseed Syrup           2      10.00
# 3          4     Chef Anton's Cajun Seasoning           2      22.00
# 4          5           Chef Anton's Gumbo Mix           2      21.35
# 5          6     Grandma's Boysenberry Spread           2      25.00
# 6          7  Uncle Bob's Organic Dried Pears           7      30.00
# 7          8       Northwoods Cranberry Sauce           2      40.00
# 8          9                  Mishi Kobe Niku           6      97.00
# 9         10                            Ikura           8      31.00

# %%
categories
# Out:
#    CategoryID    CategoryName                Description
# 0           1       Beverages                Soft drinks
# 1           2      Condiments    Sweet and savory sauces
# 2           3     Confections                   Desserts
# 3           4  Dairy Products                    Cheeses
# 4           5  Grains/Cereals                     Breads
# 5           6    Meat/Poultry             Prepared meats
# 6           7         Produce  Dried fruit and bean curd
# 7           8         Seafood           Seaweed and fish

# %%
products.merge(right=categories, on='CategoryID', how='inner').head(10)
# Out:
#    ProductID                ProductName  CategoryID  UnitPrice CategoryName  \
# 0          1                       Chai           1       18.0    Beverages
# 1          2                      Chang           1       19.0    Beverages
# 2         24         Guaraná Fantástica           1        4.5    Beverages
# 3         34              Sasquatch Ale           1       14.0    Beverages
# 4         35             Steeleye Stout           1       18.0    Beverages
# 5         38              Côte de Blaye           1      263.5    Beverages
# 6         39           Chartreuse verte           1       18.0    Beverages
# 7         43                Ipoh Coffee           1       46.0    Beverages
# 8         67  Laughing Lumberjack Lager           1       14.0    Beverages
# 9         70              Outback Lager           1       15.0    Beverages
#
#    Description
# 0  Soft drinks
# 1  Soft drinks
# 2  Soft drinks
# 3  Soft drinks
# 4  Soft drinks
# 5  Soft drinks
# 6  Soft drinks
# 7  Soft drinks
# 8  Soft drinks
# 9  Soft drinks

# %% [markdown]
# Na potrzeby ćwiczenia zmieniamy nazwę kolumny

# %%
categories.rename({'CategoryID' : 'ID'}, axis='columns', inplace=True)

# %%
products.merge(right=categories, on='CategoryID', how='inner').head(10)        # Teraz nie ma kolumny 'CategoryID' w obydwu DF, dlatego nie zadziała
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8108\2092564752.py in <module>
# ----> 1 products.merge(right=categories, on='CategoryID', how='inner').head(10)        # Teraz nie ma kolumny 'CategoryID' w obydwu DF, dlatego nie zadziała
#
# C:\Programowanie\Anaconda\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9352         from pandas.core.reshape.merge import merge
#    9353
# -> 9354         return merge(
#    9355             self,
#    9356             right,
#
# C:\Programowanie\Anaconda\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
# --> 107     op = _MergeOperation(
#     108         left,
#     109         right,
#
# C:\Programowanie\Anaconda\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     698             self.right_join_keys,
#     699             self.join_names,
# --> 700         ) = self._get_merge_keys()
#     701
#     702         # validate the merge keys dtypes. We may need to coerce
#
# C:\Programowanie\Anaconda\lib\site-packages\pandas\core\reshape\merge.py in _get_merge_keys(self)
#    1095                     if not is_rkey(rk):
#    1096                         if rk is not None:
# -> 1097                             right_keys.append(right._get_label_or_level_values(rk))
#    1098                         else:
#    1099                             # work-around for merge_asof(right_index=True)
#
# C:\Programowanie\Anaconda\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1838             values = self.axes[axis].get_level_values(key)._values
#    1839         else:
# -> 1840             raise KeyError(key)
#    1841
#    1842         # Check for duplicates
#
# KeyError: 'CategoryID'

# %% [markdown]
#  Teraz nie ma kolumny 'CategoryID' w obydwu DF. Dlatego używamy left_on i right_on

# %%
products.merge(right=categories, how='inner',left_on='CategoryID',right_on='ID').head(10)
# Out:
#    ProductID                ProductName  CategoryID  UnitPrice  ID  \
# 0          1                       Chai           1       18.0   1
# 1          2                      Chang           1       19.0   1
# 2         24         Guaraná Fantástica           1        4.5   1
# 3         34              Sasquatch Ale           1       14.0   1
# 4         35             Steeleye Stout           1       18.0   1
# 5         38              Côte de Blaye           1      263.5   1
# 6         39           Chartreuse verte           1       18.0   1
# 7         43                Ipoh Coffee           1       46.0   1
# 8         67  Laughing Lumberjack Lager           1       14.0   1
# 9         70              Outback Lager           1       15.0   1
#
#   CategoryName  Description
# 0    Beverages  Soft drinks
# 1    Beverages  Soft drinks
# 2    Beverages  Soft drinks
# 3    Beverages  Soft drinks
# 4    Beverages  Soft drinks
# 5    Beverages  Soft drinks
# 6    Beverages  Soft drinks
# 7    Beverages  Soft drinks
# 8    Beverages  Soft drinks
# 9    Beverages  Soft drinks

# %% [markdown]
# Co by się stało jakby oba DF miały taką samą nazwę kolumny, po której nie chcemy jej łączyć

# %%
products.rename({"ProductName" : "Name"}, axis='columns', inplace=True)

# %%
categories.rename({"CategoryName" : "Name"}, axis='columns', inplace=True)

# %%
products.head()
# Out:
#    ProductID                          Name  CategoryID  UnitPrice
# 0          1                          Chai           1      18.00
# 1          2                         Chang           1      19.00
# 2          3                 Aniseed Syrup           2      10.00
# 3          4  Chef Anton's Cajun Seasoning           2      22.00
# 4          5        Chef Anton's Gumbo Mix           2      21.35

# %%
categories.head()
# Out:
#    ID            Name              Description
# 0   1       Beverages              Soft drinks
# 1   2      Condiments  Sweet and savory sauces
# 2   3     Confections                 Desserts
# 3   4  Dairy Products                  Cheeses
# 4   5  Grains/Cereals                   Breads

# %%
products.merge(right=categories, how='inner',left_on='CategoryID',right_on='ID').head(10)
# Out:
#    ProductID                     Name_x  CategoryID  UnitPrice  ID     Name_y  \
# 0          1                       Chai           1       18.0   1  Beverages
# 1          2                      Chang           1       19.0   1  Beverages
# 2         24         Guaraná Fantástica           1        4.5   1  Beverages
# 3         34              Sasquatch Ale           1       14.0   1  Beverages
# 4         35             Steeleye Stout           1       18.0   1  Beverages
# 5         38              Côte de Blaye           1      263.5   1  Beverages
# 6         39           Chartreuse verte           1       18.0   1  Beverages
# 7         43                Ipoh Coffee           1       46.0   1  Beverages
# 8         67  Laughing Lumberjack Lager           1       14.0   1  Beverages
# 9         70              Outback Lager           1       15.0   1  Beverages
#
#    Description
# 0  Soft drinks
# 1  Soft drinks
# 2  Soft drinks
# 3  Soft drinks
# 4  Soft drinks
# 5  Soft drinks
# 6  Soft drinks
# 7  Soft drinks
# 8  Soft drinks
# 9  Soft drinks

# %% [markdown]
# Pandas zrobił suffix dla Name z lewego DF _x, a z prawego DF _y. Żeby zmienić suffixy używamy suffixes=[]

# %%
products.merge(right=categories, how='inner',left_on='CategoryID',right_on='ID', suffixes=['_prod', '_cat']).head(10)
# Out:
#    ProductID                  Name_prod  CategoryID  UnitPrice  ID   Name_cat  \
# 0          1                       Chai           1       18.0   1  Beverages
# 1          2                      Chang           1       19.0   1  Beverages
# 2         24         Guaraná Fantástica           1        4.5   1  Beverages
# 3         34              Sasquatch Ale           1       14.0   1  Beverages
# 4         35             Steeleye Stout           1       18.0   1  Beverages
# 5         38              Côte de Blaye           1      263.5   1  Beverages
# 6         39           Chartreuse verte           1       18.0   1  Beverages
# 7         43                Ipoh Coffee           1       46.0   1  Beverages
# 8         67  Laughing Lumberjack Lager           1       14.0   1  Beverages
# 9         70              Outback Lager           1       15.0   1  Beverages
#
#    Description
# 0  Soft drinks
# 1  Soft drinks
# 2  Soft drinks
# 3  Soft drinks
# 4  Soft drinks
# 5  Soft drinks
# 6  Soft drinks
# 7  Soft drinks
# 8  Soft drinks
# 9  Soft drinks

# %% [markdown]
# #### parametr sort=True

# %%
products.merge(right=categories, how='inner',left_on='CategoryID',right_on='ID', suffixes=['_prod', '_cat'], sort=True).head(10)
# Out:
#    ProductID                  Name_prod  CategoryID  UnitPrice  ID   Name_cat  \
# 0          1                       Chai           1       18.0   1  Beverages
# 1          2                      Chang           1       19.0   1  Beverages
# 2         24         Guaraná Fantástica           1        4.5   1  Beverages
# 3         34              Sasquatch Ale           1       14.0   1  Beverages
# 4         35             Steeleye Stout           1       18.0   1  Beverages
# 5         38              Côte de Blaye           1      263.5   1  Beverages
# 6         39           Chartreuse verte           1       18.0   1  Beverages
# 7         43                Ipoh Coffee           1       46.0   1  Beverages
# 8         67  Laughing Lumberjack Lager           1       14.0   1  Beverages
# 9         70              Outback Lager           1       15.0   1  Beverages
#
#    Description
# 0  Soft drinks
# 1  Soft drinks
# 2  Soft drinks
# 3  Soft drinks
# 4  Soft drinks
# 5  Soft drinks
# 6  Soft drinks
# 7  Soft drinks
# 8  Soft drinks
# 9  Soft drinks

# %% [markdown]
# Łączenie po indexie. Zmieniamy aby ID było indexem

# %%
categories.set_index('ID', inplace=True)

# %%
categories.head()
# Out:
#               Name              Description
# ID
# 1        Beverages              Soft drinks
# 2       Condiments  Sweet and savory sauces
# 3      Confections                 Desserts
# 4   Dairy Products                  Cheeses
# 5   Grains/Cereals                   Breads

# %%
products.merge(right=categories, how='inner',left_on='CategoryID',right_index=True, suffixes=['_prod', '_cat'], sort=True).head(10)
# Out:
#     ProductID                  Name_prod  CategoryID  UnitPrice   Name_cat  \
# 0           1                       Chai           1       18.0  Beverages
# 1           2                      Chang           1       19.0  Beverages
# 23         24         Guaraná Fantástica           1        4.5  Beverages
# 33         34              Sasquatch Ale           1       14.0  Beverages
# 34         35             Steeleye Stout           1       18.0  Beverages
# 37         38              Côte de Blaye           1      263.5  Beverages
# 38         39           Chartreuse verte           1       18.0  Beverages
# 42         43                Ipoh Coffee           1       46.0  Beverages
# 66         67  Laughing Lumberjack Lager           1       14.0  Beverages
# 69         70              Outback Lager           1       15.0  Beverages
#
#     Description
# 0   Soft drinks
# 1   Soft drinks
# 23  Soft drinks
# 33  Soft drinks
# 34  Soft drinks
# 37  Soft drinks
# 38  Soft drinks
# 42  Soft drinks
# 66  Soft drinks
# 69  Soft drinks

# %% [markdown]
# ## Ćwiczenie
# opcje polecenia merge

# %%
import pandas as pd 
import numpy as np

# %%
suppliers = pd.read_csv('./data/northwind-mongo-master/suppliers.csv', usecols=['SupplierID', 'CompanyName', 'City'])

# %%
products = pd.read_csv('./data/northwind-mongo-master/products.csv', usecols=['ProductID', 'ProductName', 'SupplierID'])

# %%
SupProd = suppliers.merge(right=products, on='SupplierID')

# %%
SupProd
# Out:
#     SupplierID                 CompanyName           City  ProductID  \
# 0            1              Exotic Liquids         London          1
# 1            1              Exotic Liquids         London          2
# 2            1              Exotic Liquids         London          3
# 3            2  New Orleans Cajun Delights    New Orleans          4
# 4            2  New Orleans Cajun Delights    New Orleans          5
# ..         ...                         ...            ...        ...
# 72          27          Escargots Nouveaux       Montceau         58
# 73          28                Gai pâturage         Annecy         59
# 74          28                Gai pâturage         Annecy         60
# 75          29            Forêts d'érables  Ste-Hyacinthe         61
# 76          29            Forêts d'érables  Ste-Hyacinthe         62
#
#                      ProductName
# 0                           Chai
# 1                          Chang
# 2                  Aniseed Syrup
# 3   Chef Anton's Cajun Seasoning
# 4         Chef Anton's Gumbo Mix
# ..                           ...
# 72        Escargots de Bourgogne
# 73          Raclette Courdavault
# 74             Camembert Pierrot
# 75                Sirop d'érable
# 76                Tarte au sucre
#
# [77 rows x 5 columns]

# %%
suppliers.set_index('SupplierID', inplace=True)

# %%
suppliers.head()
# Out:
#                                    CompanyName         City
# SupplierID
# 1                               Exotic Liquids       London
# 2                   New Orleans Cajun Delights  New Orleans
# 3                    Grandma Kelly's Homestead    Ann Arbor
# 4                                Tokyo Traders        Tokyo
# 5           Cooperativa de Quesos 'Las Cabras'       Oviedo

# %%
SupProd = suppliers.merge(right=products, left_index=True, right_on='SupplierID')

# %%
SupProd
# Out:
#                            CompanyName           City  ProductID  \
# SupplierID
# 1                       Exotic Liquids         London          1
# 1                       Exotic Liquids         London          2
# 1                       Exotic Liquids         London          3
# 2           New Orleans Cajun Delights    New Orleans          4
# 2           New Orleans Cajun Delights    New Orleans          5
# ...                                ...            ...        ...
# 27                  Escargots Nouveaux       Montceau         58
# 28                        Gai pâturage         Annecy         59
# 28                        Gai pâturage         Annecy         60
# 29                    Forêts d'érables  Ste-Hyacinthe         61
# 29                    Forêts d'érables  Ste-Hyacinthe         62
#
#                              ProductName
# SupplierID
# 1                                   Chai
# 1                                  Chang
# 1                          Aniseed Syrup
# 2           Chef Anton's Cajun Seasoning
# 2                 Chef Anton's Gumbo Mix
# ...                                  ...
# 27                Escargots de Bourgogne
# 28                  Raclette Courdavault
# 28                     Camembert Pierrot
# 29                        Sirop d'érable
# 29                        Tarte au sucre
#
# [77 rows x 4 columns]

# %%
products.set_index('SupplierID', inplace=True)

# %%
products.head()
# Out:
#             ProductID                   ProductName
# SupplierID
# 1                   1                          Chai
# 1                   2                         Chang
# 1                   3                 Aniseed Syrup
# 2                   4  Chef Anton's Cajun Seasoning
# 2                   5        Chef Anton's Gumbo Mix

# %%
SupProd = suppliers.merge(right=products, left_index=True, right_index=True)

# %%
SupProd
# Out:
#                            CompanyName           City  ProductID  \
# SupplierID
# 1                       Exotic Liquids         London          1
# 1                       Exotic Liquids         London          2
# 1                       Exotic Liquids         London          3
# 2           New Orleans Cajun Delights    New Orleans          4
# 2           New Orleans Cajun Delights    New Orleans          5
# ...                                ...            ...        ...
# 27                  Escargots Nouveaux       Montceau         58
# 28                        Gai pâturage         Annecy         59
# 28                        Gai pâturage         Annecy         60
# 29                    Forêts d'érables  Ste-Hyacinthe         61
# 29                    Forêts d'érables  Ste-Hyacinthe         62
#
#                              ProductName
# SupplierID
# 1                                   Chai
# 1                                  Chang
# 1                          Aniseed Syrup
# 2           Chef Anton's Cajun Seasoning
# 2                 Chef Anton's Gumbo Mix
# ...                                  ...
# 27                Escargots de Bourgogne
# 28                  Raclette Courdavault
# 28                     Camembert Pierrot
# 29                        Sirop d'érable
# 29                        Tarte au sucre
#
# [77 rows x 4 columns]

# %%
suppliers.reset_index(inplace=True)

# %%
suppliers.head()
# Out:
#    SupplierID                         CompanyName         City
# 0           1                      Exotic Liquids       London
# 1           2          New Orleans Cajun Delights  New Orleans
# 2           3           Grandma Kelly's Homestead    Ann Arbor
# 3           4                       Tokyo Traders        Tokyo
# 4           5  Cooperativa de Quesos 'Las Cabras'       Oviedo

# %%
SupProd = suppliers.merge(right=products, left_on='SupplierID', right_index=True)

# %%
SupProd
# Out:
#     SupplierID                 CompanyName           City  ProductID  \
# 0            1              Exotic Liquids         London          1
# 0            1              Exotic Liquids         London          2
# 0            1              Exotic Liquids         London          3
# 1            2  New Orleans Cajun Delights    New Orleans          4
# 1            2  New Orleans Cajun Delights    New Orleans          5
# ..         ...                         ...            ...        ...
# 26          27          Escargots Nouveaux       Montceau         58
# 27          28                Gai pâturage         Annecy         59
# 27          28                Gai pâturage         Annecy         60
# 28          29            Forêts d'érables  Ste-Hyacinthe         61
# 28          29            Forêts d'érables  Ste-Hyacinthe         62
#
#                      ProductName
# 0                           Chai
# 0                          Chang
# 0                  Aniseed Syrup
# 1   Chef Anton's Cajun Seasoning
# 1         Chef Anton's Gumbo Mix
# ..                           ...
# 26        Escargots de Bourgogne
# 27          Raclette Courdavault
# 27             Camembert Pierrot
# 28                Sirop d'érable
# 28                Tarte au sucre
#
# [77 rows x 5 columns]

# %%
products.reset_index(inplace=True)

# %%
products.head()
# Out:
#    SupplierID  ProductID                   ProductName
# 0           1          1                          Chai
# 1           1          2                         Chang
# 2           1          3                 Aniseed Syrup
# 3           2          4  Chef Anton's Cajun Seasoning
# 4           2          5        Chef Anton's Gumbo Mix

# %%
SupProd = suppliers.merge(right=products, on='SupplierID')

# %%
SupProd
# Out:
#     SupplierID                 CompanyName           City  ProductID  \
# 0            1              Exotic Liquids         London          1
# 1            1              Exotic Liquids         London          2
# 2            1              Exotic Liquids         London          3
# 3            2  New Orleans Cajun Delights    New Orleans          4
# 4            2  New Orleans Cajun Delights    New Orleans          5
# ..         ...                         ...            ...        ...
# 72          27          Escargots Nouveaux       Montceau         58
# 73          28                Gai pâturage         Annecy         59
# 74          28                Gai pâturage         Annecy         60
# 75          29            Forêts d'érables  Ste-Hyacinthe         61
# 76          29            Forêts d'érables  Ste-Hyacinthe         62
#
#                      ProductName
# 0                           Chai
# 1                          Chang
# 2                  Aniseed Syrup
# 3   Chef Anton's Cajun Seasoning
# 4         Chef Anton's Gumbo Mix
# ..                           ...
# 72        Escargots de Bourgogne
# 73          Raclette Courdavault
# 74             Camembert Pierrot
# 75                Sirop d'érable
# 76                Tarte au sucre
#
# [77 rows x 5 columns]

# %% [markdown]
# ## Łączenie danych z większej ilości obiektów DF
# .merge() nie posiada możliwości łączenia kilku DF na raz. Dlatego najpierw robimy jedno łączenie, a następnie drugie.

# %%
import pandas as pd 
import numpy as np

# %%
products = pd.read_csv('./data/northwind-mongo-master/products.csv', usecols=['ProductID', 'ProductName', 
                                                                              'CategoryID', 'UnitPrice'])

# %%
categories = pd.read_csv('./data/northwind-mongo-master/categories1.csv', usecols=['CategoryID','CategoryName', 'Description'])

# %%
orders = pd.read_csv('./data/northwind-mongo-master/order-details.csv')

# %%
products.head()
# Out:
#    ProductID                   ProductName  CategoryID  UnitPrice
# 0          1                          Chai           1      18.00
# 1          2                         Chang           1      19.00
# 2          3                 Aniseed Syrup           2      10.00
# 3          4  Chef Anton's Cajun Seasoning           2      22.00
# 4          5        Chef Anton's Gumbo Mix           2      21.35

# %%
categories.head()
# Out:
#    CategoryID    CategoryName              Description
# 0           1       Beverages              Soft drinks
# 1           2      Condiments  Sweet and savory sauces
# 2           3     Confections                 Desserts
# 3           4  Dairy Products                  Cheeses
# 4           5  Grains/Cereals                   Breads

# %%
orders.head()
# Out:
#    OrderID  ProductID  UnitPrice  Quantity  Discount
# 0    10248         11       14.0        12       0.0
# 1    10248         42        9.8        10       0.0
# 2    10248         72       34.8         5       0.0
# 3    10249         14       18.6         9       0.0
# 4    10249         51       42.4        40       0.0

# %%
prod_cat = products.merge(categories, on='CategoryID')

# %%
prod_cat.head(2)
# Out:
#    ProductID ProductName  CategoryID  UnitPrice CategoryName  Description
# 0          1        Chai           1       18.0    Beverages  Soft drinks
# 1          2       Chang           1       19.0    Beverages  Soft drinks

# %%
prod_cat_ord = prod_cat.merge(orders, on='ProductID')

# %%
prod_cat_ord.head(2)
# Out:
#    ProductID ProductName  CategoryID  UnitPrice_x CategoryName  Description  \
# 0          1        Chai           1         18.0    Beverages  Soft drinks
# 1          1        Chai           1         18.0    Beverages  Soft drinks
#
#    OrderID  UnitPrice_y  Quantity  Discount
# 0    10285         14.4        45       0.2
# 1    10294         14.4        18       0.0

# %% [markdown]
# W dwóch DF są kolumny UnitPrice, dlatego trzeba się nad nim zastanowić co z nim zrobić. Mogło być tak, że w DF orders są ceny po jakich kiedyś został dany artykuł sprzedany, a w DF products już aktualna cena, ale obywie mogą być potrzebne do analizy.

# %%
prod_cat_ord = prod_cat.merge(orders, on='ProductID', suffixes=['_Prod', '_Order'])

# %%
prod_cat_ord
# Out:
#       ProductID                ProductName  CategoryID  UnitPrice_Prod  \
# 0             1                       Chai           1           18.00
# 1             1                       Chai           1           18.00
# 2             1                       Chai           1           18.00
# 3             1                       Chai           1           18.00
# 4             1                       Chai           1           18.00
# ...         ...                        ...         ...             ...
# 2150         64  Wimmers gute Semmelknödel           5           33.25
# 2151         64  Wimmers gute Semmelknödel           5           33.25
# 2152         64  Wimmers gute Semmelknödel           5           33.25
# 2153         64  Wimmers gute Semmelknödel           5           33.25
# 2154         64  Wimmers gute Semmelknödel           5           33.25
#
#         CategoryName  Description  OrderID  UnitPrice_Order  Quantity  \
# 0          Beverages  Soft drinks    10285            14.40        45
# 1          Beverages  Soft drinks    10294            14.40        18
# 2          Beverages  Soft drinks    10317            14.40        20
# 3          Beverages  Soft drinks    10348            14.40        15
# 4          Beverages  Soft drinks    10354            14.40        12
# ...              ...          ...      ...              ...       ...
# 2150  Grains/Cereals       Breads    10968            33.25         4
# 2151  Grains/Cereals       Breads    11031            33.25        20
# 2152  Grains/Cereals       Breads    11053            33.25        25
# 2153  Grains/Cereals       Breads    11072            33.25       130
# 2154  Grains/Cereals       Breads    11077            33.25         2
#
#       Discount
# 0         0.20
# 1         0.00
# 2         0.00
# 3         0.15
# 4         0.00
# ...        ...
# 2150      0.00
# 2151      0.00
# 2152      0.20
# 2153      0.00
# 2154      0.03
#
# [2155 rows x 10 columns]

# %%
prod_cat_ord.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2155 entries, 0 to 2154
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ProductID        2155 non-null   int64
#  1   ProductName      2155 non-null   object
#  2   CategoryID       2155 non-null   int64
#  3   UnitPrice_Prod   2155 non-null   float64
#  4   CategoryName     2155 non-null   object
#  5   Description      2155 non-null   object
#  6   OrderID          2155 non-null   int64
#  7   UnitPrice_Order  2155 non-null   float64
#  8   Quantity         2155 non-null   int64
#  9   Discount         2155 non-null   float64
# dtypes: float64(3), int64(4), object(3)
# memory usage: 588.7 KB

# %% [markdown]
# ## Ćwiczenie
# merge wielu obiektów

# %%
import pandas as pd 
import numpy as np

# %%
suppliers = pd.read_csv('./data/northwind-mongo-master/suppliers.csv', usecols=['SupplierID', 'CompanyName', 'City'])

# %%
products = pd.read_csv('./data/northwind-mongo-master/products.csv', usecols=['ProductID', 'ProductName', 
                                                                              'SupplierID', 'CategoryID'])

# %%
categories = pd.read_csv('./data/northwind-mongo-master/categories1.csv', usecols=['CategoryID','CategoryName'],
                                                                        index_col='CategoryID')

# %%
suppliers.head(2)
# Out:
#    SupplierID                 CompanyName         City
# 0           1              Exotic Liquids       London
# 1           2  New Orleans Cajun Delights  New Orleans

# %%
products.head(2)
# Out:
#    ProductID ProductName  SupplierID  CategoryID
# 0          1        Chai           1           1
# 1          2       Chang           1           1

# %%
categories.head(2)
# Out:
#            CategoryName
# CategoryID
# 1             Beverages
# 2            Condiments

# %%
prod_cat = products.merge(categories, left_on='CategoryID', right_index=True)

# %%
prod_cat.head(2)
# Out:
#    ProductID ProductName  SupplierID  CategoryID CategoryName
# 0          1        Chai           1           1    Beverages
# 1          2       Chang           1           1    Beverages

# %%
prod_cat_sup = prod_cat.merge(suppliers, on='SupplierID')

# %%
prod_cat_sup.head(2)
# Out:
#    ProductID ProductName  SupplierID  CategoryID CategoryName     CompanyName  \
# 0          1        Chai           1           1    Beverages  Exotic Liquids
# 1          2       Chang           1           1    Beverages  Exotic Liquids
#
#      City
# 0  London
# 1  London

# %% [markdown]
# Wielokrotne łączenie w jednym wierszu

# %%
prod_cat_sup_in1 = products.merge(categories, left_on='CategoryID', right_index=True).merge(suppliers, on='SupplierID')

# %%
prod_cat_sup_in1.head(2)
# Out:
#    ProductID ProductName  SupplierID  CategoryID CategoryName     CompanyName  \
# 0          1        Chai           1           1    Beverages  Exotic Liquids
# 1          2       Chang           1           1    Beverages  Exotic Liquids
#
#      City
# 0  London
# 1  London
